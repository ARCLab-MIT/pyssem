# %%
import pickle

# %%
# open scenario-properties-baseline.pkl
with open('../scenario-properties-baseline.pkl', 'rb') as f:
    scenario_properties = pickle.load(f)

# %%
scenario_properties.FLM_steps['N_32kg'].sum()
# Out:
# 16000
